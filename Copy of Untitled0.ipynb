# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\rohithsai\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: filelock in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (2.32.2)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rohithsai\anaconda3\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\rohithsai\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
from datasets import load_dataset
dataset = load_dataset("cfilt/iitb-english-hindi")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 1659083
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 520
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 2507
#     })
# })

# %%
len(dataset['train'])
# Out:
# 1659083

# %%
max_length = 256

# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
# Out:
# c:\Users\RohithSai\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# c:\Users\RohithSai\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
article = dataset['validation'][2]['translation']['en']
inputs = tokenizer(article, return_tensors="pt")

translated_tokens = model.generate(
	**inputs, max_length=256
)
tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
# Out:
# 'एमएनएपी शिक्षकों के राष्ट्रपति, राजस्वीवर ने इस पुरस्कार को पेश करने के द्वारा स्कूल की प्रतिष्ठा की.'

# %%
dataset['validation'][2]['translation']['hi']
# Out:
# 'मनपा शिक्षक संघ के अध्यक्ष राजेश गवरे ने स्कूल को भेंट देकर सराहना की।'

# %%
def preprocess_function(examples):
  inputs = [ex["en"] for ex in examples["translation"]]
  targets = [ex["hi"] for ex in examples["translation"]]

  model_inputs = tokenizer(inputs, max_length=max_length, truncation=True)
  labels = tokenizer(targets,max_length=max_length, truncation=True)
  model_inputs["labels"] = labels["input_ids"]

  return model_inputs

# %%
tokenized_datasets_validation = dataset['validation'].map(
	preprocess_function,
	batched= True,
	remove_columns=dataset["validation"].column_names,
	batch_size = 2
)

tokenized_datasets_test = dataset['test'].map(
	preprocess_function,
	batched= True,
	remove_columns=dataset["test"].column_names,
	batch_size = 2)

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model)

# %%
# Access the layers and freeze the specified number of layers
# Specify the number of layers to freeze from the end

for parameter in model.parameters():
	parameter.requires_grad = True
num_layers_to_freeze = 10 # Adjust as needed
for layer_index, layer in enumerate(model.model.encoder.layers):
	print
	if layer_index < len(model.model.encoder.layers) - num_layers_to_freeze:
		for parameter in layer.parameters():
			parameter.requires_grad = False

num_layers_to_freeze = 10 # Adjust as needed
for layer_index, layer in enumerate(model.model.decoder.layers):
	print
	if layer_index < len(model.model.encoder.layers) - num_layers_to_freeze:
		for parameter in layer.parameters():
			parameter.requires_grad = False

# %%
# !pip install evaluate
# Out:
# Requirement already satisfied: evaluate in c:\users\rohithsai\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (2.21.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (2.32.2)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.3.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (0.24.6)
# Requirement already satisfied: packaging in c:\users\rohithsai\anaconda3\lib\site-packages (from evaluate) (23.2)
# Requirement already satisfied: filelock in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.13.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rohithsai\anaconda3\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests>=2.19.0->evaluate) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\rohithsai\anaconda3\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.3)
# Requirement already satisfied: six>=1.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)

# %%
# !pip install sacrebleu
# Out:
# Requirement already satisfied: sacrebleu in c:\users\rohithsai\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: portalocker in c:\users\rohithsai\anaconda3\lib\site-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: regex in c:\users\rohithsai\anaconda3\lib\site-packages (from sacrebleu) (2023.10.3)
# Requirement already satisfied: tabulate>=0.8.9 in c:\users\rohithsai\anaconda3\lib\site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\rohithsai\anaconda3\lib\site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in c:\users\rohithsai\anaconda3\lib\site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in c:\users\rohithsai\anaconda3\lib\site-packages (from sacrebleu) (5.2.1)
# Requirement already satisfied: pywin32>=226 in c:\users\rohithsai\anaconda3\lib\site-packages (from portalocker->sacrebleu) (305.1)

# %%
import evaluate

metric = evaluate.load("sacrebleu")

import numpy as np


def compute_metrics(eval_preds):
	preds, labels = eval_preds
	# In case the model returns more than the prediction logits
	if isinstance(preds, tuple):
		preds = preds[0]

	decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)

	# Replace -100s in the labels as we can't decode them
	labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
	decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

	# Some simple post-processing
	decoded_preds = [pred.strip() for pred in decoded_preds]
	decoded_labels = [[label.strip()] for label in decoded_labels]

	result = metric.compute(predictions=decoded_preds, references=decoded_labels)
	return {"bleu": result["score"]}

# %%
import torch
from transformers import Seq2SeqTrainingArguments

# Check if a GPU is available and define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)
training_args = Seq2SeqTrainingArguments(
    f"finetuned-nlp-en-hi",
    gradient_checkpointing=False,  # Disabling gradient checkpointing
    per_device_train_batch_size=16,  # Reducing batch size
    learning_rate=1e-5,
    warmup_steps=2,
    max_steps=1000,  # Reducing the number of steps
    fp16=True,
    optim='adafactor',
    per_device_eval_batch_size=16,
    metric_for_best_model="eval_bleu",
    predict_with_generate=True,
    push_to_hub=False,
)
# Out:
# WARNING:tensorflow:From c:\Users\RohithSai\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
	model,
	training_args,
	train_dataset=tokenized_datasets_test,
	eval_dataset=tokenized_datasets_validation,
	data_collator=data_collator,
	tokenizer=tokenizer,
	compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# max_steps is given, it will override any value given in num_train_epochs
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\rohithsai\anaconda3\lib\site-packages (4.42.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (4.2.0)
# Requirement already satisfied: fastapi in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.112.2)
# Requirement already satisfied: ffmpy in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.4.0)
# Requirement already satisfied: gradio-client==1.3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (1.3.0)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.27.2)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.24.6)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (6.4.4)
# Requirement already satisfied: jinja2<4.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (3.8.4)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (2.5.3)
# Requirement already satisfied: pydub in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.6.2)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (4.11.0)
# Requirement already satisfied: urllib3~=2.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio) (0.30.6)
# Requirement already satisfied: fsspec in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio-client==1.3.0->gradio) (2024.3.1)
# Requirement already satisfied: websockets<13.0,>=10.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from gradio-client==1.3.0->gradio) (12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rohithsai\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (2.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: certifi in c:\users\rohithsai\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\rohithsai\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rohithsai\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\rohithsai\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in c:\users\rohithsai\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rohithsai\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rohithsai\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rohithsai\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\rohithsai\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.14.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.3.5)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\rohithsai\anaconda3\lib\site-packages (from fastapi->gradio) (0.38.2)
# Requirement already satisfied: colorama in c:\users\rohithsai\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\rohithsai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohithsai\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohithsai\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohithsai\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %%
import gradio as gr


def translate(text):
  inputs = tokenizer(text, return_tensors="pt").to(device)
  translated_tokens = model.generate(**inputs, max_length=256)
  results = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
  return results


#Creating the User Interface Space
interface = gr.Interface(fn=translate,inputs=gr.Textbox(lines=2, placeholder='Text to translate'),
						outputs='text')
#launching the interface
interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Save the fine-tuned model and tokenizer
model.save_pretrained("finetuned-nlp-en-hi")
tokenizer.save_pretrained("finetuned-nlp-en-hi")

# Load the fine-tuned model and tokenizer for inference
tokenizer = AutoTokenizer.from_pretrained("finetuned-nlp-en-hi")
model = AutoModelForSeq2SeqLM.from_pretrained("finetuned-nlp-en-hi")
model.to(device)

# Define the translation function
def translate(text):
    inputs = tokenizer(text, return_tensors="pt").to(device)
    translated_tokens = model.generate(**inputs, max_length=256)
    results = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return results

# Create the Gradio interface
interface = gr.Interface(fn=translate,
                         inputs=gr.Textbox(lines=2, placeholder='Text to translate'),
                         outputs='text')

# Launch the interface
interface.launch()
# Out:
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[61949]], 'forced_eos_token_id': 0}
# c:\Users\RohithSai\anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Running on local URL:  http://127.0.0.1:7861
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import gradio as gr
import torch
from transformers import Seq2SeqTrainingArguments

# Check if a GPU is available and define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device)

# Load the fine-tuned model and tokenizer for inference
tokenizer = AutoTokenizer.from_pretrained("finetuned-nlp-en-hi")
model = AutoModelForSeq2SeqLM.from_pretrained("finetuned-nlp-en-hi")
model.to(device)

# Define the translation function
def translate(text):
    inputs = tokenizer(text, return_tensors="pt").to(device)
    translated_tokens = model.generate(**inputs, max_length=256)
    results = tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[0]
    return results

# Create the Gradio interface
interface = gr.Interface(fn=translate,
                         inputs=gr.Textbox(lines=2, placeholder='Text to translate'),
                         outputs='text')

# Launch the interface
interface.launch()
# Out:
# c:\Users\RohithSai\Anaconda3\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
